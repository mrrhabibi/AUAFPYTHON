# %%
#This is how we manage more than one condition.
is_infected = True
is_adult = True

if is_infected:
    print('Sorry. You can\'t get vaccinated if you are not a Covid-positive.')
elif is_adult :
    print('You can visit the nearist clinic to get vaccinated.')
else:
    print('You are not old enough to get the vaccine.')
# Out:
# Sorry. You can't get vaccinated if you are not a Covid-positive.

# %%
#we need to use capital T,F with True and False.
is_old = True

if is_old:
    print('You can get the vaccine.')
else:
    print('You are not old enough to get the vaccine')
# Out:
# You can get the vaccine.

# %%
# = ASSIGNMENTM, == EQUALITY
